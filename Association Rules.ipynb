# %% [markdown]
# ### Importing modules

# %%
import pandas as pd
# import missingno as msno

# %% [markdown]
# ### Loading Dataset

# %%
df = pd.read_excel('G1.xlsx')

df
# Out:
#      FldFileNumberPatient     f_job      m_job  f_age  m_age  \
# 0                 H_10062  خانه دار       آزاد     34     39
# 1                 H_12609  خانه دار  باطري ساز     48     47
# 2                 H_19230  خانه دار  باطري ساز     33     37
# 3                 H_19354  خانه دار     راننده     34     41
# 4                 H_27444  خانه دار      نظامي     39     42
# ...                   ...       ...        ...    ...    ...
# 4285               W_9451  خانه دار       آزاد     39     40
# 4286               W_9885  خانه دار       آزاد     31     39
# 4287             W2_39218  خانه دار       آزاد     33     31
# 4288             W2_51997  خانه دار       آزاد     40     43
# 4289               ؟؟؟؟؟؟  خانه دار       آزاد     34     33
#
#      f_educational_level m_educational_level
# 0                 متوسطه            راهنمایی
# 1               راهنمایی            راهنمایی
# 2        دانشجوی کاردانی     دانشجوی کاردانی
# 3                 متوسطه            راهنمایی
# ...

# %% [markdown]
# ### EDA

# %%
# df.shape
# df.describe()
# df.info()

# msno.bar(df)

df.isnull().sum()
# Out:
# FldFileNumberPatient     0
# f_job                    0
# m_job                    0
# f_age                    0
# m_age                    0
# f_educational_level     26
# m_educational_level     40
# dtype: int64

# %% [markdown]
# ### Remove NULLs

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Remove unnecessary columns

# %%
df.drop('FldFileNumberPatient' , axis=1, inplace=True)

df
# Out:
#          f_job      m_job  f_age  m_age f_educational_level  \
# 0     خانه دار       آزاد     34     39              متوسطه
# 1     خانه دار  باطري ساز     48     47            راهنمایی
# 2     خانه دار  باطري ساز     33     37     دانشجوی کاردانی
# 3     خانه دار     راننده     34     41              متوسطه
# 4     خانه دار      نظامي     39     42              متوسطه
# ...        ...        ...    ...    ...                 ...
# 4285  خانه دار       آزاد     39     40              متوسطه
# 4286  خانه دار       آزاد     31     39             ابتدایی
# 4287  خانه دار       آزاد     33     31            راهنمایی
# 4288  خانه دار       آزاد     40     43             کاردانی
# 4289  خانه دار       آزاد     34     33     دانشجوی کاردانی
#
#      m_educational_level
# 0               راهنمایی
# 1               راهنمایی
# 2        دانشجوی کاردانی
# 3               راهنمایی
# 4        دانشجوی کاردانی
# ...                  ...
# 4285            راهنمایی
# 4286             ابتدایی
# ...
